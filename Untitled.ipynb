# %%
"hello world!"
# Out:
# 'hello world!'

# %%
def f(i):
    return i*2

# %%
def g(i):
    return i*5

# %%
def k(i):
    return i * 10

# %%
two_list_array = []
for i in range(0,20):
    two_list_array.append([f(i),g(i), k(i)])

# %%
nasihyoung = []
for [i,j,k] in two_list_array:
    rr = i*2+j*3+k*5

# %%
nasihyoung = []
for [i,j,k] in two_list_array:
    rr = i*2+j*3+k*5
    if rr % 5 == 0:
        nasihyoung.append(i*2+j*3+k*5)
nasihyoung[:5]
# Out:
# [0, 345, 690, 1035]

# %%
rrr = [ (i*2+j*3+k*5) if (i*2+j*3+k*5)%5 == 0 else 5 for [i,j,k] in two_list_array ]
rrr[:10]
# Out:
# [0, 5, 5, 5, 5, 345, 5, 5, 5, 5]

# %%
nasihyoung = []
for [i,j,k] in two_list_array:
    rr = i*2+j*3+k*5
    if rr % 5 == 0:
        nasihyoung.append(rr)
    else:
        nasinhyoung.append(5)
nasihyoung[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       5         nasihyoung.append(rr)
#       6     else:
# ----> 7         nasinhyoung.append(5)
#       8 nasihyoung[:10]
#
# NameError: name 'nasinhyoung' is not defined

# %%
x = [ i for i in range(100)]
y = [ i*2+5 for i in x]
y_parabola = [i*2+5 for i in x]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y_parabola)

# %%
import matplotlib.pyplot as plt

from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d

ax = plt.figure().add_subplot(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.contour(X, Y, Z, extend3d=True, cmap=cm.coolwarm)

plt.show()

# %% [markdown]
# $ \lim_{h\rightarrow 0} \frac{f(x+h) - f(x)}{h}$

# %%
b

# %%
import numpy as np
import matplotlib.pyplot as plt

# 함수 정의
def f(x):
    return 3*x**3 + 6*x

def derivative(x):
    return 3*x** + 1

# x 범위
x = np.linspace(-5, 5, 400)

# 원래 함수와 미분 함수
y = zz(x)
# 실제 해석적 미분 (검증용)
y_prime = 6*x

# 그래프 그리기
plt.figure(figsize=(8,6))
plt.plot(x, y, label=r"$f(x) = 3x^3 + 6x$", color="blue")
plt.plot(x, y_prime, label=r"$f'(x) = 9x^2 + 6$", color="red", linestyle="--")

# 좌표축 꾸미기
plt.axhline(0, color="black", linewidth=0.8)
plt.axvline(0, color="black", linewidth=0.8)
plt.title("Function and Its Derivative")
plt.legend()
plt.grid(True)
plt.show()

# %%
lambdaf = lambda x : x+1

# %%
lamda_result=[]
for i in [11,12,13,14]:
    lamda_result.append(lambdaf(i))
lamda_result
# Out:
# [12, 13, 14, 15]

# %%
list( map( lambdaf, [1,2,3,4]))
# Out:
# [2, 3, 4, 5]

# %%
lambdag = lambda x : x*x

# %%
list( map( lambdag, [1,2,3,4]))
# Out:
# [1, 4, 9, 16]

# %%
def gg(i) : return i**5

# %%
funcs = [ 
lambda x: x*2,
    lambda x: x*2,
    lambda x: x*4,
    lambda x: x*23,
    lambda x: x*28,
  gg
]

# %%
[f(10) for f in funcs]
# Out:
# [20, 20, 40, 230, 280, 100000]

# %%
list(map ( lambda v: v(3), funcs))
# Out:
# [6, 6, 12, 69, 84, 243]
